# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50, 101, size = (50, 5)) # 亂數產生50人、5科分數
df = pd.DataFrame(scores, 
             columns = ["國文", "英文", "數學", "地理", "歷史"],
             index = range(1,51)
            )
df.index.name = "學號"
df.columns.name = "科目"
df
# Out:
# 科目   國文   英文   數學   地理   歷史
# 學號
# 1    62   70   93   64   79
# 2    89   97   55   75   75
# 3    62   65   77   82   81
# 4    56   74   97   55   95
# 5   100   78   76   81   94
# 6    61   75   73   54   74
# 7    89   79   53   61   59
# 8    82   53   82   77   58
# 9    71   53   58   62   75
# 10   53   75   61   85   72
# 11   95   62   50   95   55
# 12   66   85   53   96   81
# 13   96   86   72   90   95
# 14   99   95   59   86   79
# 15   97   86  100   73   82
# 16   76   64   56   84   54
# 17   93   55   79   95   61
# 18   99   93   58   96   81
# 19  100   75   97   94   52
# 20   63   52   61   97   99
# 21   65   60   86   75   95
# 22   61   76   61   61   74
# 23   77   53   96   79   75
# 24   80   62   82  100   86
# 25   72   81   59   60   72
# 26   75   76   88   55   82
# 27   96   90  100   72   86
# 28   95   62   65   54   89
# 29   99   90   74   53   51
# 30   79   57   61   67   69
# 31   71   79   80   98   98
# 32   57   71   98   83   62
# 33   69  100   87   67   55
# 34   94   80   68   78   67
# 35   74  100   82   54   79
# 36   79   61   66   94   81
# 37   57   68   63   83   93
# 38  100   87   55   78   57
# 39   77   55   90   96   67
# 40  100   80   91   54   75
# 41   94   86   92   94   82
# 42   51   62   79   88   83
# 43   83   83   92   65   82
# 44   92   75   97   67  100
# 45   90   95   71   63   99
# 46   94   82   55   81   60
# 47   80   93   52   89   75
# 48  100   51   65   88   94
# 49   78   74   83   93   88
# 50   95   79   81   73   72

# %%
sum_value = df.sum(axis = 1) # 每人分數總和
mean_value = df.mean(axis = 1) # 每人分數平均

# %%
df["總分"] = sum_value
df["平均"] = mean_value

# %%
# 網址： https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

df1 = df.sort_values(by = "總分", ascending = False) # 依據總分作排序，ascending = False 由大到小

# %%
rank_value = df1["總分"].rank(ascending = False, method = "max")
df1["排名"] = rank_value
df1
# Out:
# 科目   國文   英文   數學   地理   歷史   總分    平均    排名
# 學號
# 41   94   86   92   94   82  448  89.6   1.0
# 27   96   90  100   72   86  444  88.8   2.0
# 13   96   86   72   90   95  439  87.8   3.0
# 15   97   86  100   73   82  438  87.6   4.0
# 44   92   75   97   67  100  431  86.2   5.0
# 5   100   78   76   81   94  429  85.8   6.0
# 18   99   93   58   96   81  427  85.4   7.0
# 31   71   79   80   98   98  426  85.2   8.0
# 14   99   95   59   86   79  418  83.6  11.0
# 19  100   75   97   94   52  418  83.6  11.0
# 45   90   95   71   63   99  418  83.6  11.0
# 49   78   74   83   93   88  416  83.2  12.0
# 24   80   62   82  100   86  410  82.0  13.0
# 43   83   83   92   65   82  405  81.0  14.0
# 40  100   80   91   54   75  400  80.0  16.0
# 50   95   79   81   73   72  400  80.0  16.0
# 48  100   51   65   88   94  398  79.6  17.0
# 2    89   97   55   75   75  391  78.2  18.0
# 35   74  100   82   54   79  389  77.8  20.0
# 47   80   93   52   89   75  389  77.8  20.0
# 34   94   80   68   78   67  387  77.4  21.0
# 39   77   55   90   96   67  385  77.0  22.0
# 17   93   55   79   95   61  383  76.6  23.0
# 21   65   60   86   75   95  381  76.2  26.0
# 12   66   85   53   96   81  381  76.2  26.0
# 36   79   61   66   94   81  381  76.2  26.0
# 23   77   53   96   79   75  380  76.0  27.0
# 33   69  100   87   67   55  378  75.6  28.0
# 38  100   87   55   78   57  377  75.4  30.0
# 4    56   74   97   55   95  377  75.4  30.0
# 26   75   76   88   55   82  376  75.2  31.0
# 20   63   52   61   97   99  372  74.4  33.0
# 46   94   82   55   81   60  372  74.4  33.0
# 32   57   71   98   83   62  371  74.2  34.0
# 1    62   70   93   64   79  368  73.6  35.0
# 29   99   90   74   53   51  367  73.4  37.0
# 3    62   65   77   82   81  367  73.4  37.0
# 28   95   62   65   54   89  365  73.0  38.0
# 37   57   68   63   83   93  364  72.8  39.0
# 42   51   62   79   88   83  363  72.6  40.0
# 11   95   62   50   95   55  357  71.4  41.0
# 8    82   53   82   77   58  352  70.4  42.0
# 10   53   75   61   85   72  346  69.2  43.0
# 25   72   81   59   60   72  344  68.8  44.0
# 7    89   79   53   61   59  341  68.2  45.0
# 6    61   75   73   54   74  337  67.4  46.0
# 16   76   64   56   84   54  334  66.8  47.0
# 30   79   57   61   67   69  333  66.6  49.0
# 22   61   76   61   61   74  333  66.6  49.0
# 9    71   53   58   62   75  319  63.8  50.0
